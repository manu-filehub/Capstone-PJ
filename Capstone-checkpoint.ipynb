# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Customer-churn-Records.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %%
# 11. Check the percentage of missing data and handle accordingly.

# %%
df.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
# 12. How many rows and columns are there in the dataset?

# %%
df.shape
# Out:
# (10000, 18)

# %%
rows, cols =df.shape
print(f"The dataset has {rows} rows and {cols} columns.")
# Out:
# The dataset has 10000 rows and 18 columns.

# %%
#13. What is the distribution of churned vs. non-churned customers?

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7962
# 1    2038
# Name: count, dtype: int64

# %%
df['Exited'].value_counts(normalize=True)*100
# Out:
# Exited
# 0    79.62
# 1    20.38
# Name: proportion, dtype: float64

# %%
sns.countplot(x='Exited',data=df,palette=['green','red'])
plt.title('Churned vs non-churned Customers')
plt.xlabel('Exited (0=Retained, 1=Churned)')
plt.ylabel('Number of Customers')
plt.show()
# Out:
# C:\Users\nayak\AppData\Local\Temp\ipykernel_6884\3929842554.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Exited',data=df,palette=['green','red'])

# %%
# About 20% customers have Churned , While 80% remain with Bank.

# %%
#14. What is the distribution of EstimatedSalary of churned and retained Customers?

# %%
df.groupby('Exited')['EstimatedSalary'].describe()
# Out:
#          count           mean           std    min        25%         50%  \
# Exited
# 0       7962.0   99726.853141  57399.956717  90.07  50783.295   99620.355
# 1       2038.0  101509.908783  57932.623392  11.58  51924.020  102489.335
#
#                 75%        max
# Exited
# 0       148602.4450  199992.48
# 1       152443.8575  199808.10

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Exited',y='EstimatedSalary',data=df,palette=['green','red'])
plt.title('Distribution of EstimatedSalary- Churned vs Retained Customers')
plt.xlabel('Exited(0=Retained,1=Churned)')
plt.ylabel('Estimated Salary')
plt.show()
# Out:
# C:\Users\nayak\AppData\Local\Temp\ipykernel_6884\3890800965.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Exited',y='EstimatedSalary',data=df,palette=['green','red'])

# %%
# Both Churned and Retained customers have similar salary distributions,So estimated salary is not a major factor in customer churn for data.

# %%
# 15. How do churn rates vary by Gender, Geography, and IsActiveMember?

# %%
 #churn rate vary by Genger

# %%
churn_gender=df.groupby('Gender')['Exited'].mean()*100
print(churn_gender)
# Out:
# Gender
# Female    25.071539
# Male      16.474253
# Name: Exited, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Gender',y='Exited',data=df,estimator='mean',palette='pastel')
plt.title('Churn Rate by Gender')
plt.ylabel('Churn Rate (%)')
plt.show()
# Out:
# C:\Users\nayak\AppData\Local\Temp\ipykernel_6884\2934609559.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender',y='Exited',data=df,estimator='mean',palette='pastel')

# %%
#Female Customers have a higher churn Rate.

# %%
 #churn rate vary by Geography

# %%
churn_geography=df.groupby('Geography')['Exited'].mean()*100
print(churn_geography)
# Out:
# Geography
# France     16.174711
# Germany    32.443204
# Spain      16.673395
# Name: Exited, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Geography',y='Exited',data=df,estimator='mean',palette='muted')
plt.title('Churn Rate by Geography')
plt.ylabel('Churn Rate (%)')
plt.show()
# Out:
# C:\Users\nayak\AppData\Local\Temp\ipykernel_6884\707093323.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Geography',y='Exited',data=df,estimator='mean',palette='muted')

# %%
#Churn rate is highest among German Customers.

# %%
 #churn Rate by Active Membership

# %%
churn_Activemembership=df.groupby('IsActiveMember')['Exited'].mean()*100
print(churn_Activemembership)
# Out:
# IsActiveMember
# 0    26.871520
# 1    14.269074
# Name: Exited, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='IsActiveMember',y='Exited',data=df,estimator='mean',palette='coolwarm')
plt.title('Churn Rate by Active Membership')
plt.ylabel('Churn Rate (%)')
plt.xticks([0,1],['Inactive','Active'])
plt.show()
# Out:
# C:\Users\nayak\AppData\Local\Temp\ipykernel_6884\2505570173.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='IsActiveMember',y='Exited',data=df,estimator='mean',palette='coolwarm')

# %%
# 16. What is the average CreditScore, Balance, and EstimatedSalary of churned vs. retained customers?

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %%
avg_values=df.groupby('Exited')[['CreditScore','Balance','EstimatedSalary']].mean()
print(avg_values)
# Out:
#         CreditScore       Balance  EstimatedSalary
# Exited
# 0        651.837855  72742.750663     99726.853141
# 1        645.414622  91109.476006    101509.908783

# %%
# Note: 0 is for retained and 1 is for Churned

# %%
17. #How does Age impact churn? Plot histograms and boxplots for churned and non-churned groups.
# Out:
# 17.0

# %%
#Histogram
plt.figure(figsize=(6,4))
sns.histplot(data=df,x='Age',hue='Exited',kde=True,bins=20,palette='coolwarm')
plt.title('Age Distribution:Churned vs Retained customers')
plt.xlabel('Age')
plt.ylabel('Number of customers')
plt.legend(title='Exited',labels=['Retained(0)','Churned(1)'])
plt.show()

# %%
#Boxplot
plt.figure(figsize=(6,5))
sns.boxplot(x='Exited',y='Age',data=df,palette='Set2')
plt.title('Age vs Churn status')
plt.xlabel('Exited(0=Retained,1=Churned)')
plt.ylabel('Age')
plt.show()
# Out:
# C:\Users\nayak\AppData\Local\Temp\ipykernel_6884\2785628990.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Exited',y='Age',data=df,palette='Set2')

# %%
df.groupby('Exited')['Age'].mean()
# Out:
# Exited
# 0    37.408063
# 1    44.835623
# Name: Age, dtype: float64

# %%
#Churned customers have a average age og 44.8 compared to 37.4 for Retained.Older Customers are more likely to churn.

# %%
#18. Is there any correlation among numeric features like CreditScore, Balance, and EstimatedSalary?

# %%
#select numeric columns
num_cols=['CreditScore','Balance','EstimatedSalary']
#calculate correlation matrix
corr_matrix=df[num_cols].corr()
print(corr_matrix)
# Out:
#                  CreditScore   Balance  EstimatedSalary
# CreditScore         1.000000  0.006268        -0.001384
# Balance             0.006268  1.000000         0.012797
# EstimatedSalary    -0.001384  0.012797         1.000000

# %%
plt.figure(figsize=(6,5))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('correlation among CreditScore, Balance, and EstimatedSalary')
plt.show()

# %%
#19. What does a heatmap reveal about feature interactions with churn?

# %%
Num_cols=['CreditScore','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary','Exited']

corr=df[Num_cols].corr()
print(corr)
# Out:
#                  CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore         1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure              0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance             0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts       0.012238 -0.030680  0.013444 -0.304180       1.000000
# HasCrCard          -0.005458 -0.011721  0.022583 -0.014858       0.003183
# IsActiveMember      0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary    -0.001384 -0.007201  0.007784  0.012797       0.014204
# Exited             -0.026771  0.285296 -0.013656  0.118577      -0.047611
#
#                  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# CreditScore      -0.005458        0.025651        -0.001384 -0.026771
# Age              -0.011721        0.085472        -0.007201  0.285296
# ...

# %%
plt.figure(figsize=(6,5))
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Heatmap:Feature interaction with Churn')
plt.show()

# %%
'''Age and Balance show a positive correlation with Churn, indicating that older customers and with higher account balance are more likely to leave the Bank.
IsActivemember and Numofproducts have a negative correlation with churn, means customers who are active are less likely to Churn.
EstimatedSalary and Tenure show almost no correlation with churn,meaning they have minimal influence on wheather a customer stay or leave.'''
# Out:
# 'Age and Balance show a positive correlation with Churn, indicating that older customers and with higher account balance are more likely to leave the Bank.\nIsActivemember and Numofproducts have a negative correlation with churn, means customers who are active are less likely to Churn.\nEstimatedSalary and Tenure show almost no correlation with churn,meaning they have minimal influence on wheather a customer stay or leave.'

# %%
#20. Are there outliers in Balance, CreditScore, or Age that are mostly associated with churn?

# %%
numeric_cols=['CreditScore','Age','Balance']
plt.figure(figsize=(15,4))
for i, col in enumerate(numeric_cols,1):
    plt.subplot(1,3,i)
    sns.boxplot(x='Exited',y=col,data=df,palette='Set2')
    plt.title(f'{col} vs Churn')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\nayak\AppData\Local\Temp\ipykernel_6884\303351568.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Exited',y=col,data=df,palette='Set2')
# C:\Users\nayak\AppData\Local\Temp\ipykernel_6884\303351568.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Exited',y=col,data=df,palette='Set2')
# C:\Users\nayak\AppData\Local\Temp\ipykernel_6884\303351568.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Exited',y=col,data=df,palette='Set2')

# %%
#21. Group customers into age brackets (e.g.,18-30 as Adults, 30-50 as middle age and 50-100 as seniors.). How does churn rate change across them?

# %%
bins=[18,30,50,100]
labels=['Adult(18-30)','Middle Age(30-50)','Senior(50-100)']
df['AgeGroups']=pd.cut(df['Age'],bins=bins,labels=labels,right=False)

# %%
df.head()

# %%
Churn_by_agegroup=df.groupby('AgeGroups')['Exited'].mean()*100
print(Churn_by_agegroup)

# %%
#Visulize churn rate by Age groups

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=Churn_by_agegroup.index,y=Churn_by_agegroup.values,palette='Set2')
plt.title('Churn Rate by AgeGroup')
plt.ylabel('Churn Rate(%)')
plt.xlabel('Age Group')
plt.show()

# %%
#22. Are customers with only one product (NumOfProducts = 1) more likely to churn than those with multiple?

# %%
Churn_by_products=df.groupby('NumOfProducts')['Exited'].mean()*100
print(Churn_by_products)

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=Churn_by_products.index,y=Churn_by_products.values,palette='coolwarm')
plt.title('Churn Rate by Number of Products')
plt.xlabel('Number of Products')
plt.xlabel('Churn Rate(%)')
plt.show()

# %%
df['NumOfProducts'].value_counts()

# %%
'''ChurnRate decreases from 1 to 2 products but spikes sharply for 3 and 4 products.That means moderate engagement(2 products) promotes loyalty.
and under-engagement(1 product)and over-engagement(3 and 4 products)may lead to customer disssatisfaction.'''
